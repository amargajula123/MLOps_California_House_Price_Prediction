# %%
import boto3

s3 = boto3.client('s3')
local_file = r"D:\ML_Projects\MLOps_California_House_Price_Prediction\notebook\shutill2.txt"
bucket_name = "My_New_1st_S3_Bucket"
s3_key = "notebook/shutill2.txt"

s3.upload_file(Filename=local_file, Bucket=bucket_name, Key=s3_key)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[3], line 8
#       5 bucket_name = "My_New_1st_S3_Bucket"
#       6 s3_key = "notebook/shutill2.txt"
# ----> 8 s3.upload_file(Filename=local_file, Bucket=bucket_name, Key=s3_key)
#
# File d:\ML_Projects\MLOps_California_House_Price_Prediction\venv\lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File d:\ML_Projects\MLOps_California_House_Price_Prediction\venv\lib\site-packages\boto3\s3\inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)
#     172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# ...

# %%
aws configure
# Out:
#   Cell In[6], line 1
#     aws configure
#         ^
# SyntaxError: invalid syntax

# %%
aws --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 aws --version
#
# NameError: name 'aws' is not defined
